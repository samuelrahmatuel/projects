# %% [markdown]
# # Data Understanding
# * species = Penguin species (Chinstrap, Adélie, or Gentoo)
# * island = Island name (Dream, Torgersen, or Biscoe) in the Palmer Archipelago (Antarctica)
# * culmen_length_mm = Culmen length of penguin (mm)
# * culmen_depth_mm = Culmen depth of penguin (mm)
# * flipper_length_mm = flipper length of penguin (mm)
# * body_mass_g = Body mass of penguin (g)
# * sex = Penguin sex

# %% [markdown]
# # Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# <a id = "1" ></a><br>
# # Load Data

# %%
df = sns.load_dataset('penguins')

# %% [markdown]
# <a id = "2" ></a><br>
# # Check Data

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.shape
# Out:
# (344, 7)

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # Features

# %% [markdown]
# ## 1. Species
# ### Kesimpulan
# Ada 3 Spesies, yaitu :
# 1. Adelie
# 2. Chinstrap
# 3. Gentoo
#
# **Spesies Yang paling banyak adalah Adelie 152**
#
# **Spesies Yang paling sedikit adalah Chinstrap 68**

# %%
df.species.describe()
# Out:
# count        344
# unique         3
# top       Adelie
# freq         152
# Name: species, dtype: object

# %%
df["species"].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.histplot(x = "species", data = df)
plt.show()

# %% [markdown]
# ## 2. Island
# ### Kesimpulan
# Ada 3 Pulau yaitu :
# 1. Biscoe
# 2. Dream
# 3. Torgersen
#
#
# **Pulau Yang paling banyak dihuni adalah Biscoe 168**
#
# **Pulau Yang paling sedikit dihuni adalah Torgersen 52**

# %%
df.island.describe()
# Out:
# count        344
# unique         3
# top       Biscoe
# freq         168
# Name: island, dtype: object

# %%
df["island"].value_counts()
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
sns.histplot(x = "island", data = df)
plt.show()

# %% [markdown]
# ## 3. Jenis Kelamin
# ### Kesimpulan
# Ada 2 Jenis Kelamin yaitu :
# 1. Jantan
# 2. Betina
#
# ada 10 data kosong pada kolom jenis kelamin dan 1 undefined
#
# **Jenis Kelamin jantan sebanyak 168**
#
# **Jenis Kelamin betina sebanyak 165**

# %%
df.sex.value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
df["sex"].isnull().sum()
# Out:
# 11

# %%
sns.histplot(x = "sex", data= df)
plt.show()

# %% [markdown]
# ## Analisa Data

# %% [markdown]
# ### Kesimpulan
#
# 1. **Penguins yang tinggal di Pulau Biscoe memiliki panjang flipper dan berat badan tinggi.**
# 2. **Penguins Gentoo memilki panjang flipper dan berat badan paling tinggi.**

# %%
df[["species","flipper_length_mm"]].groupby(["species"],as_index = False).mean().sort_values(by ="flipper_length_mm", ascending = False)
# Out:
#      species  flipper_length_mm
# 2     Gentoo         217.186992
# 1  Chinstrap         195.823529
# 0     Adelie         189.953642

# %%
df[["species","body_mass_g"]].groupby(["species"],as_index = False).mean().sort_values(by ="body_mass_g", ascending = False)
# Out:
#      species  body_mass_g
# 2     Gentoo  5076.016260
# 1  Chinstrap  3733.088235
# 0     Adelie  3700.662252

# %%
df[["island","flipper_length_mm"]].groupby(["island"],as_index = False).mean().sort_values(by ="flipper_length_mm", ascending = False)
# Out:
#       island  flipper_length_mm
# 0     Biscoe         209.706587
# 1      Dream         193.072581
# 2  Torgersen         191.196078

# %%
df[["island","body_mass_g"]].groupby(["island"],as_index = False).mean().sort_values(by ="body_mass_g", ascending = False)
# Out:
#       island  body_mass_g
# 0     Biscoe  4716.017964
# 1      Dream  3712.903226
# 2  Torgersen  3706.372549

# %%
sns.histplot(x = "flipper_length_mm", data = df, hue = "species")
plt.title("Panjang Flipper vs Spesies", size=15)
plt.show()

# %%
sns.barplot(x = "island", y = "flipper_length_mm", data = df, hue = "sex")
plt.title("Panjang Flipper vs Pulau", size=15)
plt.show()

# %%
warnings.filterwarnings('ignore')
g = sns.catplot(x = "species", y = "body_mass_g", kind = "bar",data = df, size = 7 )
plt.title("Berat Penguin vs Spesies", size=15)
plt.show()

# %%
g = sns.factorplot(x = "island", y = "body_mass_g", kind = "bar",data = df, size = 7 )
plt.title("Berat Penguin VS Pulau", size=15)
plt.show()

# %%
sns.FacetGrid(df, col="island", row="sex").map(sns.histplot, "flipper_length_mm")
plt.show()

# %%
sns.FacetGrid(df, col="island", row="sex").map(sns.histplot, "body_mass_g")
plt.show()

# %%
sns.FacetGrid(df, col="species", row="sex").map(sns.histplot, "flipper_length_mm")
plt.show()

# %%
sns.FacetGrid(df, col="species", row="sex").map(sns.histplot, "body_mass_g")
plt.show()
